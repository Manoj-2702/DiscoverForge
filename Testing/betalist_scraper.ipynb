# %%
import requests
from bs4 import BeautifulSoup

def scrape_grow_truncate_text(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        # Find all divs with class 'myContainer'
        containers = soup.find_all('div', class_='myContainer')
        
        # Ensure there is at least a second 'myContainer'
        if containers and len(containers) >= 2:
            second_container = containers[1]  # Get the second div
            
            # Find all 'grow truncate' divs within the second 'myContainer'
            grow_truncate_divs = second_container.find_all('div', class_='grow truncate')
            
            # Extract text from each 'grow truncate' div and store in a list
            grow_truncate_texts = [div.get_text(strip=True) for div in grow_truncate_divs]
            
            return grow_truncate_texts
        else:
            print("The second specified container was not found on the page.")
            return []
    else:
        print(f"Failed to fetch the page, status code: {response.status_code}")
        return []

# Example usage
url = "https://betalist.com/topics"
texts = scrape_grow_truncate_text(url)
for text in texts:
    print(text)
# Out:
# 3D
# 3D Printing
# 3D Technology
# Accounting
# Active Lifestyle
# Ad Targeting
# Adventure Travel
# Advertising
# Advertising Exchanges
# Advertising Networks
# Advertising Platforms
# Advice
# Agriculture
# Algorithms
# All Markets
# All Students
# Analytics
# Android
# Angel Investing
# Animal Feed
# App Discovery
# Apple Watch
# Application Performance Monitoring
# Application Platforms
# Apps
# App Stores
# Architecture
# Art
# Artificial Intelligence
# Artists Globally
# Audio
# Augmented Reality
# Automotive
# B2B
# Babies
# Baby Accessories
# Banking
# Banking Tech
# Batteries
# Beauty
# Bicycles
# Big Data
# Big Data Analytics
# Billing
# Biometrics
# Biotechnology
# Bitcoin
# Blockchain
# Blogging Platforms
# Boating Industry
# Books
# Bots
# Brand Marketing
# Bridging Online and Offline
# Broadcasting
# Browser Extensions
# Building Products
# Business Analytics
# Business Development
# Business Information Systems
# Business Intelligence
# Business Productivity
# Business Services
# Business Travelers
# Career Management
# Career Planning
# Cars
# Casual Games
# Cause Marketing
# Celebrity
# Charities
# Charity
# Charter Schools
# Chat
# Child Care
# Classifieds
# Clean Technology
# Cloud-Based Music
# Cloud Computing
# Cloud Data Services
# Cloud Infrastructure
# Cloud Management
# Coffee
# Collaboration
# Collaborative Consumption
# Collectibles
# College Campuses
# College Recruiting
# Colleges
# Comics
# Commercial Real Estate
# Communications Hardware
# Communications Infrastructure
# Communities
# Comparison Shopping
# Computers
# Computer Vision
# Concerts
# Console Gaming
# Construction
# Consulting
# Consumer Behavior
# Consumer Electronics
# Consumer Finance
# Consumer Goods
# Consumer Internet
# Consumer Lending
# Consumers
# Contact Management
# Content
# Content Creators
# Content Delivery
# Content Discovery
# Content Syndication
# Cooking
# Corporate IT
# Corporate Training
# Corporate Wellness
# Cosmetics
# Coupons
# Coworking
# Craft Beer
# Creative
# Creative Industries
# Credit
# Credit Cards
# CRM
# Crowdfunding
# Crowdsourcing
# Cryptocurrencies
# Curated Web
# Customer Service
# Customer Support Tools
# Custom Retail
# Cyber Security
# Databases
# Data Centers
# Data Integration
# Data Mining
# Data Privacy
# Data Security
# Data Visualization
# Deals
# Deep Information Technology
# Design
# Designers
# Developer APIs
# Developer Tools
# Development Platforms
# Digital Entertainment
# Digital Media
# Digital Signage
# Direct Marketing
# Direct Sales
# Discounts
# Disruptive Models
# Distribution
# DIY
# Doctors
# Document Management
# Domains
# Drones
# Drop-in Audio
# EBooks
# E-Books
# E-Commerce
# E-Commerce Platforms
# Education
# Educational Games
# Edutainment
# Electric Vehicles
# Electronics
# Email
# Email Marketing
# Email Newsletters
# Embedded Hardware and Software
# Emerging Markets
# Employer Benefits Programs
# Employment
# Energy
# Engineering Firms
# English Speaking World
# Enterprise 2.0
# Enterprise Resource Planning
# Enterprises
# Enterprise Security
# Enterprise Software
# Entertainment
# Entertainment Industry
# Entrepreneur
# Environmental Innovation
# Event Management
# Events
# Exercise
# Facebook Applications
# Families
# Fantasy Sports
# Fashion
# Feedback Tools
# Field Support Services
# File Sharing
# Film
# Film Production
# Finance
# Finance Technology
# Financial Exchanges
# Financial Services
# Financial Services Investments
# Fitness
# Flash Sales
# Food & Beverages
# Forums
# Fraud Detection
# Freelancers
# Freemium
# FreetoPlay Gaming
# Gadget
# Gambling
# Game Mechanics
# Games
# Gamification
# General Public Worldwide
# Geospatial
# Gift Card
# Gift Exchange
# Gift Registries
# Golf Equipment
# Google Apps
# Government Innovation
# Governments
# Gps
# Graphics
# Green
# Green Building
# Green Consumer Goods
# Groceries
# Group SMS
# Guides
# Guide to Nightlife
# Handmade
# Hardware
# Hardware + Software
# Health and Insurance
# Health and Wellness
# Health Care
# Health Care Information Technology
# Healthcare Services
# Hedge Funds
# High Schools
# High School Students
# High Tech
# Home Automation
# Home Decor
# Home & Garden
# Home Owners
# Home Renovation
# Hospitality
# Hotels
# Human Computer Interaction
# Human Resource Automation
# Human Resources
# IaaS
# Identity
# Identity Management
# Image Recognition
# Impact Investing
# Incubators
# Independent Music
# Independent Music Labels
# Indians
# Industrial
# Information Security
# Information Services
# Information Technology
# Infrastructure
# Innovation Engineering
# Innovation Management
# Insurance
# Insurance Companies
# Intellectual Property
# Interest Graph
# Interior Design
# Internet
# Internet Infrastructure
# Internet Marketing
# Internet of Things
# Internet Radio Market
# Internet Service Providers
# Internet TV
# Investment Management
# Invest Online
# iOS
# iPad
# iPhone
# IT and Cybersecurity
# IT Management
# Jewelry
# Job Boards
# Job Market
# Job search
# Journalism
# K-12 Education
# Kids
# Knowledge Management
# Language Learning
# Law Enforcement
# Lead Generation
# Lead Management
# Legal
# Leisure
# Life Sciences
# Lifestyle
# Lifestyle Businesses
# Lifestyle Products
# Lighting
# Local
# Local Advertising
# Local Based Services
# Local Businesses
# Local Commerce
# Local Coupons
# Local Search
# Local Services
# Location Based Services
# Logistics
# Loyalty Programs
# Mac Applications
# Machine Learning
# Manufacturing
# Maps
# Marketing Automation
# Marketplaces
# Market Research
# Mass Customization
# Match-Making
# Material Science
# Media
# Medical
# Medical Devices
# Medical Professionals
# Medical Start Ups
# Meeting Software
# Mens Specific
# Messaging
# MicroBlogging
# Microfinance
# MMO Games
# Mobile
# Mobile Advertising
# Mobile Analytics
# Mobile Commerce
# Mobile Coupons
# Mobile Devices
# Mobile Emergency&Health
# Mobile Enterprise
# Mobile Games
# Mobile Health
# Mobile Payments
# Mobile Search
# Mobile Security
# Mobile Shopping
# Mobile Social
# Mobile Software Tools
# Mobile Video
# Mobility
# Monetization
# Moneymaking
# Mothers
# Music
# Musical Instruments
# Music Education
# Musicians
# Music Services
# Music Venues
# Natural Language Processing
# Navigation
# Networking
# Neuroscience
# New Product Development
# News
# NFT
# Nightclubs
# Nightlife
# No Code
# Non Profit
# Nonprofits
# Note taking
# Nutrition
# Office Space
# Online Auctions
# Online Dating
# Online Events
# Online Gaming
# Online Identity
# Online Rental
# Online Reservations
# Online Scheduling
# Online Shopping
# Online Travel
# Online Video Advertising
# Open Source
# Operating Systems
# Opinions
# Optimization
# Organic Food
# Outdoors
# Outsourcing
# P2P Money Transfer
# PaaS
# Parenting
# Parking
# Payments
# PC Gaming
# Peer-to-Peer
# Performance Marketing
# Performing Arts
# Personal Branding
# Personal Data
# Personal Finance
# Personal Health
# Personalization
# Pets
# Pharmaceuticals
# Photo Editing
# Photography
# Photo Sharing
# Platforms
# Podcasting
# Point of Sale
# Politics
# Polling
# Postal and Courier Services
# Predictive Analytics
# Presentations
# Price Comparison
# Printing
# Privacy
# Private School
# Private Social Networking
# Procurement
# Product Design
# Productivity Software
# Product Search
# Professional Networking
# Professional Services
# Project Management
# Promotional
# Property Management
# Psychology
# Public Relations
# Public Safety
# Public Transportation
# Publishing
# Q&A
# QR Codes
# Quantified Self
# Quantitative Marketing
# Reading Apps
# Real Estate
# Real Estate Investors
# Real Time
# Realtors
# Recipes
# Recreation
# Recruiting
# Remote Work
# Rental Housing
# Reputation
# Restaurants
# Retail
# Retail Technology
# Reviews and Recommendations
# Risk Management
# Robotics
# SaaS
# Sales and Marketing
# Sales Automation
# Search
# Search Marketing
# Security
# Self Development
# Semantic Search
# Semantic Web
# Senior Health
# SEO
# Service Providers
# Services
# Shared Services
# Shipping
# Shopping
# Skill Gaming
# Small and Medium Businesses
# Smart Building
# SMS
# Soccer
# Social Activists
# Social Bookmarking
# Social Business
# Social Commerce
# Social CRM
# Social Fundraising
# Social Games
# Social Innovation
# Social Media
# Social Media Advertising
# Social Media Marketing
# Social Media Monitoring
# Social Media Platforms
# Social Network Media
# Social News
# Social Opinion Platform
# Social Recruiting
# Social Search
# Social Television
# Social Travel
# Software
# South East Asia
# Space Travel
# Specialty Foods
# Specialty Retail
# Speech Recognition
# Sponsorship
# Sporting Goods
# Sports
# Staffing Firms
# Startups
# Stock Exchanges
# Storage
# Subscription Businesses
# Supply Chain Management
# Sustainability
# Tablets
# Task Management
# Teachers
# Teaching STEM Concepts
# Technical Continuing Education
# Technology
# Teenagers
# Telecommunications
# Telephony
# Television
# Temporary Staffing
# Test and Measurement
# Text Analytics
# Textbooks
# Therapeutics
# Ticketing
# To Do Lists
# Tourism
# Toys
# Tracking
# Trading
# Training
# Translation
# Transportation
# Travel
# Travel & Tourism
# Tutoring
# TV Production
# Twitter Applications
# Unifed Communications
# Universities
# University Students
# Usability
# User Experience Design
# User Testing
# Utilities
# Vacation Rentals
# Venture Capital
# Ventures for Good
# Video
# Video Chat
# Video Conferencing
# Video Editing
# Video Games
# Video on Demand
# Video Streaming
# Virtual Currency
# Virtualization
# Virtual Reality
# Virtual Workforces
# Virtual Worlds
# Visualization
# Visual Search
# Voice
# VoIP
# Waste Management
# Wealth Management
# Wearables
# Web3
# Web Browsers
# Web CMS
# Web Design
# Web Development
# Web Hosting
# Web Tools
# Weddings
# West Africa
# Wholesale
# Wine And Spirits
# Wireless
# Women
# Work From Home
# World
# Writers
# Writing tools
# Young Adults

# %%
categories = texts
lowercase_strings = [s.lower() for s in categories]
lowercase_strings = [s.lower().replace(" ", "-") for s in lowercase_strings]

# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_category_details(url, category):
    response = requests.get(url)
    details = []
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        container = soup.find('div', class_='infinite-startups')
        if container:
            links = container.find_all('a', class_="block whitespace-nowrap text-ellipsis overflow-hidden font-medium")
            for link in links:
                # For each link, store both its text and the href attribute
                details.append({
                    "text": link.get_text(strip=True),
                    "href": link.get('href')  # Extract the href attribute
                })
    else:
        print(f"Failed to fetch the page for {category}, status code: {response.status_code}")
    return details

def scrape_all_categories_and_save_each(base_url, categories, filename="output_sites.json"):
    data = []
    for category in categories:
        formatted_category = category.replace(' ', '-').lower()
        full_url = f"{base_url}{formatted_category}"  # Adjusting category for URL and lowercase
        print(full_url)
        category_details = scrape_category_details(full_url, category)
        # Store the category with its corresponding startups' details
        data.append({"category": category, "startups": category_details})
        # Save to JSON file after processing each category
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
    print(f"Data saved to {filename}")

# Assuming lowercase_strings is defined somewhere above this snippet
# Example category list
categories = lowercase_strings  # Use your actual categories here
base_url = "https://betalist.com/topics/"

# Run the scraping and saving process
scrape_all_categories_and_save_each(base_url, categories)
# Out:
# https://betalist.com/topics/3d
# https://betalist.com/topics/3d-printing
# https://betalist.com/topics/3d-technology
# https://betalist.com/topics/accounting
# https://betalist.com/topics/active-lifestyle
# https://betalist.com/topics/ad-targeting
# https://betalist.com/topics/adventure-travel
# https://betalist.com/topics/advertising
# https://betalist.com/topics/advertising-exchanges
# https://betalist.com/topics/advertising-networks
# https://betalist.com/topics/advertising-platforms
# https://betalist.com/topics/advice
# https://betalist.com/topics/agriculture
# https://betalist.com/topics/algorithms
# https://betalist.com/topics/all-markets
# https://betalist.com/topics/all-students
# https://betalist.com/topics/analytics
# https://betalist.com/topics/android
# https://betalist.com/topics/angel-investing
# https://betalist.com/topics/animal-feed
# https://betalist.com/topics/app-discovery
# https://betalist.com/topics/apple-watch
# https://betalist.com/topics/application-performance-monitoring
# https://betalist.com/topics/application-platforms
# https://betalist.com/topics/apps
# https://betalist.com/topics/app-stores
# https://betalist.com/topics/architecture
# https://betalist.com/topics/art
# https://betalist.com/topics/artificial-intelligence
# https://betalist.com/topics/artists-globally
# https://betalist.com/topics/audio
# https://betalist.com/topics/augmented-reality
# https://betalist.com/topics/automotive
# https://betalist.com/topics/b2b
# https://betalist.com/topics/babies
# https://betalist.com/topics/baby-accessories
# https://betalist.com/topics/banking
# https://betalist.com/topics/banking-tech
# https://betalist.com/topics/batteries
# https://betalist.com/topics/beauty
# https://betalist.com/topics/bicycles
# https://betalist.com/topics/big-data
# https://betalist.com/topics/big-data-analytics
# https://betalist.com/topics/billing
# https://betalist.com/topics/biometrics
# https://betalist.com/topics/biotechnology
# https://betalist.com/topics/bitcoin
# https://betalist.com/topics/blockchain
# https://betalist.com/topics/blogging-platforms
# https://betalist.com/topics/boating-industry
# https://betalist.com/topics/books
# https://betalist.com/topics/bots
# https://betalist.com/topics/brand-marketing
# https://betalist.com/topics/bridging-online-and-offline
# https://betalist.com/topics/broadcasting
# https://betalist.com/topics/browser-extensions
# https://betalist.com/topics/building-products
# https://betalist.com/topics/business-analytics
# https://betalist.com/topics/business-development
# https://betalist.com/topics/business-information-systems
# https://betalist.com/topics/business-intelligence
# https://betalist.com/topics/business-productivity
# https://betalist.com/topics/business-services
# https://betalist.com/topics/business-travelers
# https://betalist.com/topics/career-management
# https://betalist.com/topics/career-planning
# https://betalist.com/topics/cars
# https://betalist.com/topics/casual-games
# https://betalist.com/topics/cause-marketing
# https://betalist.com/topics/celebrity
# https://betalist.com/topics/charities
# https://betalist.com/topics/charity
# https://betalist.com/topics/charter-schools
# https://betalist.com/topics/chat
# https://betalist.com/topics/child-care
# https://betalist.com/topics/classifieds
# https://betalist.com/topics/clean-technology
# https://betalist.com/topics/cloud-based-music
# https://betalist.com/topics/cloud-computing
# https://betalist.com/topics/cloud-data-services
# https://betalist.com/topics/cloud-infrastructure
# https://betalist.com/topics/cloud-management
# https://betalist.com/topics/coffee
# https://betalist.com/topics/collaboration
# https://betalist.com/topics/collaborative-consumption
# https://betalist.com/topics/collectibles
# https://betalist.com/topics/college-campuses
# https://betalist.com/topics/college-recruiting
# https://betalist.com/topics/colleges
# https://betalist.com/topics/comics
# https://betalist.com/topics/commercial-real-estate
# https://betalist.com/topics/communications-hardware
# https://betalist.com/topics/communications-infrastructure
# https://betalist.com/topics/communities
# https://betalist.com/topics/comparison-shopping
# https://betalist.com/topics/computers
# https://betalist.com/topics/computer-vision
# https://betalist.com/topics/concerts
# https://betalist.com/topics/console-gaming
# https://betalist.com/topics/construction
# https://betalist.com/topics/consulting
# https://betalist.com/topics/consumer-behavior
# https://betalist.com/topics/consumer-electronics
# https://betalist.com/topics/consumer-finance
# https://betalist.com/topics/consumer-goods
# https://betalist.com/topics/consumer-internet
# https://betalist.com/topics/consumer-lending
# https://betalist.com/topics/consumers
# https://betalist.com/topics/contact-management
# https://betalist.com/topics/content
# https://betalist.com/topics/content-creators
# https://betalist.com/topics/content-delivery
# https://betalist.com/topics/content-discovery
# https://betalist.com/topics/content-syndication
# https://betalist.com/topics/cooking
# https://betalist.com/topics/corporate-it
# https://betalist.com/topics/corporate-training
# https://betalist.com/topics/corporate-wellness
# https://betalist.com/topics/cosmetics
# https://betalist.com/topics/coupons
# https://betalist.com/topics/coworking
# https://betalist.com/topics/craft-beer
# https://betalist.com/topics/creative
# https://betalist.com/topics/creative-industries
# https://betalist.com/topics/credit
# https://betalist.com/topics/credit-cards
# https://betalist.com/topics/crm
# https://betalist.com/topics/crowdfunding
# https://betalist.com/topics/crowdsourcing
# https://betalist.com/topics/cryptocurrencies
# https://betalist.com/topics/curated-web
# https://betalist.com/topics/customer-service
# https://betalist.com/topics/customer-support-tools
# https://betalist.com/topics/custom-retail
# https://betalist.com/topics/cyber-security
# https://betalist.com/topics/databases
# https://betalist.com/topics/data-centers
# https://betalist.com/topics/data-integration
# https://betalist.com/topics/data-mining
# https://betalist.com/topics/data-privacy
# https://betalist.com/topics/data-security
# https://betalist.com/topics/data-visualization
# https://betalist.com/topics/deals
# https://betalist.com/topics/deep-information-technology
# https://betalist.com/topics/design
# https://betalist.com/topics/designers
# https://betalist.com/topics/developer-apis
# https://betalist.com/topics/developer-tools
# https://betalist.com/topics/development-platforms
# https://betalist.com/topics/digital-entertainment
# https://betalist.com/topics/digital-media
# https://betalist.com/topics/digital-signage
# https://betalist.com/topics/direct-marketing
# https://betalist.com/topics/direct-sales
# https://betalist.com/topics/discounts
# https://betalist.com/topics/disruptive-models
# https://betalist.com/topics/distribution
# https://betalist.com/topics/diy
# https://betalist.com/topics/doctors
# https://betalist.com/topics/document-management
# https://betalist.com/topics/domains
# https://betalist.com/topics/drones
# https://betalist.com/topics/drop-in-audio
# Failed to fetch the page for drop-in-audio, status code: 404
# https://betalist.com/topics/ebooks
# https://betalist.com/topics/e-books
# https://betalist.com/topics/e-commerce
# https://betalist.com/topics/e-commerce-platforms
# https://betalist.com/topics/education
# https://betalist.com/topics/educational-games
# https://betalist.com/topics/edutainment
# https://betalist.com/topics/electric-vehicles
# https://betalist.com/topics/electronics
# https://betalist.com/topics/email
# https://betalist.com/topics/email-marketing
# https://betalist.com/topics/email-newsletters
# https://betalist.com/topics/embedded-hardware-and-software
# https://betalist.com/topics/emerging-markets
# https://betalist.com/topics/employer-benefits-programs
# https://betalist.com/topics/employment
# https://betalist.com/topics/energy
# https://betalist.com/topics/engineering-firms
# https://betalist.com/topics/english-speaking-world
# https://betalist.com/topics/enterprise-2.0
# Failed to fetch the page for enterprise-2.0, status code: 404
# https://betalist.com/topics/enterprise-resource-planning
# https://betalist.com/topics/enterprises
# https://betalist.com/topics/enterprise-security
# https://betalist.com/topics/enterprise-software
# https://betalist.com/topics/entertainment
# https://betalist.com/topics/entertainment-industry
# https://betalist.com/topics/entrepreneur
# https://betalist.com/topics/environmental-innovation
# https://betalist.com/topics/event-management
# https://betalist.com/topics/events
# https://betalist.com/topics/exercise
# https://betalist.com/topics/facebook-applications
# https://betalist.com/topics/families
# https://betalist.com/topics/fantasy-sports
# https://betalist.com/topics/fashion
# https://betalist.com/topics/feedback-tools
# Failed to fetch the page for feedback-tools, status code: 404
# https://betalist.com/topics/field-support-services
# https://betalist.com/topics/file-sharing
# https://betalist.com/topics/film
# https://betalist.com/topics/film-production
# https://betalist.com/topics/finance
# https://betalist.com/topics/finance-technology
# https://betalist.com/topics/financial-exchanges
# https://betalist.com/topics/financial-services
# https://betalist.com/topics/financial-services-investments
# https://betalist.com/topics/fitness
# https://betalist.com/topics/flash-sales
# https://betalist.com/topics/food-&-beverages
# Failed to fetch the page for food-&-beverages, status code: 404
# https://betalist.com/topics/forums
# https://betalist.com/topics/fraud-detection
# https://betalist.com/topics/freelancers
# https://betalist.com/topics/freemium
# https://betalist.com/topics/freetoplay-gaming
# https://betalist.com/topics/gadget
# https://betalist.com/topics/gambling
# https://betalist.com/topics/game-mechanics
# https://betalist.com/topics/games
# https://betalist.com/topics/gamification
# https://betalist.com/topics/general-public-worldwide
# https://betalist.com/topics/geospatial
# https://betalist.com/topics/gift-card
# https://betalist.com/topics/gift-exchange
# https://betalist.com/topics/gift-registries
# https://betalist.com/topics/golf-equipment
# https://betalist.com/topics/google-apps
# https://betalist.com/topics/government-innovation
# https://betalist.com/topics/governments
# https://betalist.com/topics/gps
# https://betalist.com/topics/graphics
# https://betalist.com/topics/green
# https://betalist.com/topics/green-building
# https://betalist.com/topics/green-consumer-goods
# https://betalist.com/topics/groceries
# https://betalist.com/topics/group-sms
# https://betalist.com/topics/guides
# https://betalist.com/topics/guide-to-nightlife
# https://betalist.com/topics/handmade
# https://betalist.com/topics/hardware
# https://betalist.com/topics/hardware-+-software
# Failed to fetch the page for hardware-+-software, status code: 404
# https://betalist.com/topics/health-and-insurance
# https://betalist.com/topics/health-and-wellness
# https://betalist.com/topics/health-care
# https://betalist.com/topics/health-care-information-technology
# https://betalist.com/topics/healthcare-services
# https://betalist.com/topics/hedge-funds
# https://betalist.com/topics/high-schools
# https://betalist.com/topics/high-school-students
# https://betalist.com/topics/high-tech
# https://betalist.com/topics/home-automation
# https://betalist.com/topics/home-decor
# https://betalist.com/topics/home-&-garden
# Failed to fetch the page for home-&-garden, status code: 404
# https://betalist.com/topics/home-owners
# https://betalist.com/topics/home-renovation
# https://betalist.com/topics/hospitality
# https://betalist.com/topics/hotels
# https://betalist.com/topics/human-computer-interaction
# https://betalist.com/topics/human-resource-automation
# https://betalist.com/topics/human-resources
# https://betalist.com/topics/iaas
# https://betalist.com/topics/identity
# https://betalist.com/topics/identity-management
# https://betalist.com/topics/image-recognition
# https://betalist.com/topics/impact-investing
# https://betalist.com/topics/incubators
# https://betalist.com/topics/independent-music
# https://betalist.com/topics/independent-music-labels
# https://betalist.com/topics/indians
# https://betalist.com/topics/industrial
# https://betalist.com/topics/information-security
# https://betalist.com/topics/information-services
# https://betalist.com/topics/information-technology
# https://betalist.com/topics/infrastructure
# https://betalist.com/topics/innovation-engineering
# https://betalist.com/topics/innovation-management
# https://betalist.com/topics/insurance
# https://betalist.com/topics/insurance-companies
# https://betalist.com/topics/intellectual-property
# https://betalist.com/topics/interest-graph
# https://betalist.com/topics/interior-design
# https://betalist.com/topics/internet
# https://betalist.com/topics/internet-infrastructure
# https://betalist.com/topics/internet-marketing
# https://betalist.com/topics/internet-of-things
# https://betalist.com/topics/internet-radio-market
# https://betalist.com/topics/internet-service-providers
# https://betalist.com/topics/internet-tv
# https://betalist.com/topics/investment-management
# https://betalist.com/topics/invest-online
# https://betalist.com/topics/ios
# https://betalist.com/topics/ipad
# https://betalist.com/topics/iphone
# https://betalist.com/topics/it-and-cybersecurity
# https://betalist.com/topics/it-management
# https://betalist.com/topics/jewelry
# https://betalist.com/topics/job-boards
# Failed to fetch the page for job-boards, status code: 404
# https://betalist.com/topics/job-market
# Failed to fetch the page for job-market, status code: 404
# https://betalist.com/topics/job-search
# Failed to fetch the page for job-search, status code: 404
# https://betalist.com/topics/journalism
# https://betalist.com/topics/k-12-education
# https://betalist.com/topics/kids
# https://betalist.com/topics/knowledge-management
# https://betalist.com/topics/language-learning
# https://betalist.com/topics/law-enforcement
# https://betalist.com/topics/lead-generation
# https://betalist.com/topics/lead-management
# https://betalist.com/topics/legal
# https://betalist.com/topics/leisure
# https://betalist.com/topics/life-sciences
# https://betalist.com/topics/lifestyle
# https://betalist.com/topics/lifestyle-businesses
# https://betalist.com/topics/lifestyle-products
# https://betalist.com/topics/lighting
# https://betalist.com/topics/local
# https://betalist.com/topics/local-advertising
# https://betalist.com/topics/local-based-services
# https://betalist.com/topics/local-businesses
# https://betalist.com/topics/local-commerce
# https://betalist.com/topics/local-coupons
# https://betalist.com/topics/local-search
# https://betalist.com/topics/local-services
# https://betalist.com/topics/location-based-services
# https://betalist.com/topics/logistics
# https://betalist.com/topics/loyalty-programs
# https://betalist.com/topics/mac-applications
# https://betalist.com/topics/machine-learning
# https://betalist.com/topics/manufacturing
# https://betalist.com/topics/maps
# https://betalist.com/topics/marketing-automation
# https://betalist.com/topics/marketplaces
# https://betalist.com/topics/market-research
# https://betalist.com/topics/mass-customization
# https://betalist.com/topics/match-making
# https://betalist.com/topics/material-science
# https://betalist.com/topics/media
# https://betalist.com/topics/medical
# https://betalist.com/topics/medical-devices
# https://betalist.com/topics/medical-professionals
# https://betalist.com/topics/medical-start-ups
# https://betalist.com/topics/meeting-software
# https://betalist.com/topics/mens-specific
# https://betalist.com/topics/messaging
# https://betalist.com/topics/microblogging
# https://betalist.com/topics/microfinance
# https://betalist.com/topics/mmo-games
# https://betalist.com/topics/mobile
# https://betalist.com/topics/mobile-advertising
# https://betalist.com/topics/mobile-analytics
# https://betalist.com/topics/mobile-commerce
# https://betalist.com/topics/mobile-coupons
# https://betalist.com/topics/mobile-devices
# https://betalist.com/topics/mobile-emergency&health
# Failed to fetch the page for mobile-emergency&health, status code: 404
# https://betalist.com/topics/mobile-enterprise
# https://betalist.com/topics/mobile-games
# https://betalist.com/topics/mobile-health
# https://betalist.com/topics/mobile-payments
# https://betalist.com/topics/mobile-search
# https://betalist.com/topics/mobile-security
# https://betalist.com/topics/mobile-shopping
# https://betalist.com/topics/mobile-social
# https://betalist.com/topics/mobile-software-tools
# https://betalist.com/topics/mobile-video
# https://betalist.com/topics/mobility
# https://betalist.com/topics/monetization
# https://betalist.com/topics/moneymaking
# https://betalist.com/topics/mothers
# https://betalist.com/topics/music
# https://betalist.com/topics/musical-instruments
# https://betalist.com/topics/music-education
# https://betalist.com/topics/musicians
# https://betalist.com/topics/music-services
# https://betalist.com/topics/music-venues
# https://betalist.com/topics/natural-language-processing
# https://betalist.com/topics/navigation
# https://betalist.com/topics/networking
# https://betalist.com/topics/neuroscience
# https://betalist.com/topics/new-product-development
# https://betalist.com/topics/news
# https://betalist.com/topics/nft
# https://betalist.com/topics/nightclubs
# https://betalist.com/topics/nightlife
# https://betalist.com/topics/no-code
# Failed to fetch the page for no-code, status code: 404
# https://betalist.com/topics/non-profit
# https://betalist.com/topics/nonprofits
# https://betalist.com/topics/note-taking
# https://betalist.com/topics/nutrition
# https://betalist.com/topics/office-space
# https://betalist.com/topics/online-auctions
# https://betalist.com/topics/online-dating
# https://betalist.com/topics/online-events
# Failed to fetch the page for online-events, status code: 404
# https://betalist.com/topics/online-gaming
# https://betalist.com/topics/online-identity
# https://betalist.com/topics/online-rental
# https://betalist.com/topics/online-reservations
# https://betalist.com/topics/online-scheduling
# https://betalist.com/topics/online-shopping
# https://betalist.com/topics/online-travel
# https://betalist.com/topics/online-video-advertising
# https://betalist.com/topics/open-source
# https://betalist.com/topics/operating-systems
# https://betalist.com/topics/opinions
# https://betalist.com/topics/optimization
# https://betalist.com/topics/organic-food
# https://betalist.com/topics/outdoors
# https://betalist.com/topics/outsourcing
# https://betalist.com/topics/p2p-money-transfer
# https://betalist.com/topics/paas
# https://betalist.com/topics/parenting
# https://betalist.com/topics/parking
# https://betalist.com/topics/payments
# https://betalist.com/topics/pc-gaming
# https://betalist.com/topics/peer-to-peer
# https://betalist.com/topics/performance-marketing
# https://betalist.com/topics/performing-arts
# https://betalist.com/topics/personal-branding
# https://betalist.com/topics/personal-data
# https://betalist.com/topics/personal-finance
# https://betalist.com/topics/personal-health
# https://betalist.com/topics/personalization
# https://betalist.com/topics/pets
# https://betalist.com/topics/pharmaceuticals
# https://betalist.com/topics/photo-editing
# https://betalist.com/topics/photography
# https://betalist.com/topics/photo-sharing
# https://betalist.com/topics/platforms
# https://betalist.com/topics/podcasting
# https://betalist.com/topics/point-of-sale
# https://betalist.com/topics/politics
# https://betalist.com/topics/polling
# https://betalist.com/topics/postal-and-courier-services
# https://betalist.com/topics/predictive-analytics
# https://betalist.com/topics/presentations
# https://betalist.com/topics/price-comparison
# https://betalist.com/topics/printing
# https://betalist.com/topics/privacy
# https://betalist.com/topics/private-school
# https://betalist.com/topics/private-social-networking
# https://betalist.com/topics/procurement
# https://betalist.com/topics/product-design
# https://betalist.com/topics/productivity-software
# https://betalist.com/topics/product-search
# https://betalist.com/topics/professional-networking
# https://betalist.com/topics/professional-services
# https://betalist.com/topics/project-management
# https://betalist.com/topics/promotional
# https://betalist.com/topics/property-management
# https://betalist.com/topics/psychology
# https://betalist.com/topics/public-relations
# https://betalist.com/topics/public-safety
# https://betalist.com/topics/public-transportation
# https://betalist.com/topics/publishing
# https://betalist.com/topics/q&a
# Failed to fetch the page for q&a, status code: 404
# https://betalist.com/topics/qr-codes
# https://betalist.com/topics/quantified-self
# https://betalist.com/topics/quantitative-marketing
# https://betalist.com/topics/reading-apps
# https://betalist.com/topics/real-estate
# https://betalist.com/topics/real-estate-investors
# https://betalist.com/topics/real-time
# https://betalist.com/topics/realtors
# https://betalist.com/topics/recipes
# https://betalist.com/topics/recreation
# https://betalist.com/topics/recruiting
# https://betalist.com/topics/remote-work
# https://betalist.com/topics/rental-housing
# https://betalist.com/topics/reputation
# https://betalist.com/topics/restaurants
# https://betalist.com/topics/retail
# https://betalist.com/topics/retail-technology
# https://betalist.com/topics/reviews-and-recommendations
# https://betalist.com/topics/risk-management
# https://betalist.com/topics/robotics
# https://betalist.com/topics/saas
# https://betalist.com/topics/sales-and-marketing
# https://betalist.com/topics/sales-automation
# https://betalist.com/topics/search
# https://betalist.com/topics/search-marketing
# https://betalist.com/topics/security
# https://betalist.com/topics/self-development
# https://betalist.com/topics/semantic-search
# https://betalist.com/topics/semantic-web
# https://betalist.com/topics/senior-health
# https://betalist.com/topics/seo
# https://betalist.com/topics/service-providers
# https://betalist.com/topics/services
# https://betalist.com/topics/shared-services
# https://betalist.com/topics/shipping
# https://betalist.com/topics/shopping
# https://betalist.com/topics/skill-gaming
# https://betalist.com/topics/small-and-medium-businesses
# https://betalist.com/topics/smart-building
# https://betalist.com/topics/sms
# https://betalist.com/topics/soccer
# https://betalist.com/topics/social-activists
# https://betalist.com/topics/social-bookmarking
# https://betalist.com/topics/social-business
# https://betalist.com/topics/social-commerce
# https://betalist.com/topics/social-crm
# https://betalist.com/topics/social-fundraising
# https://betalist.com/topics/social-games
# https://betalist.com/topics/social-innovation
# https://betalist.com/topics/social-media
# https://betalist.com/topics/social-media-advertising
# https://betalist.com/topics/social-media-marketing
# https://betalist.com/topics/social-media-monitoring
# https://betalist.com/topics/social-media-platforms
# https://betalist.com/topics/social-network-media
# https://betalist.com/topics/social-news
# https://betalist.com/topics/social-opinion-platform
# https://betalist.com/topics/social-recruiting
# https://betalist.com/topics/social-search
# https://betalist.com/topics/social-television
# https://betalist.com/topics/social-travel
# https://betalist.com/topics/software
# https://betalist.com/topics/south-east-asia
# https://betalist.com/topics/space-travel
# https://betalist.com/topics/specialty-foods
# https://betalist.com/topics/specialty-retail
# https://betalist.com/topics/speech-recognition
# https://betalist.com/topics/sponsorship
# https://betalist.com/topics/sporting-goods
# https://betalist.com/topics/sports
# https://betalist.com/topics/staffing-firms
# https://betalist.com/topics/startups
# https://betalist.com/topics/stock-exchanges
# https://betalist.com/topics/storage
# https://betalist.com/topics/subscription-businesses
# https://betalist.com/topics/supply-chain-management
# https://betalist.com/topics/sustainability
# https://betalist.com/topics/tablets
# https://betalist.com/topics/task-management
# https://betalist.com/topics/teachers
# https://betalist.com/topics/teaching-stem-concepts
# https://betalist.com/topics/technical-continuing-education
# https://betalist.com/topics/technology
# https://betalist.com/topics/teenagers
# https://betalist.com/topics/telecommunications
# https://betalist.com/topics/telephony
# https://betalist.com/topics/television
# https://betalist.com/topics/temporary-staffing
# https://betalist.com/topics/test-and-measurement
# https://betalist.com/topics/text-analytics
# https://betalist.com/topics/textbooks
# https://betalist.com/topics/therapeutics
# https://betalist.com/topics/ticketing
# https://betalist.com/topics/to-do-lists
# Failed to fetch the page for to-do-lists, status code: 404
# https://betalist.com/topics/tourism
# https://betalist.com/topics/toys
# https://betalist.com/topics/tracking
# https://betalist.com/topics/trading
# https://betalist.com/topics/training
# https://betalist.com/topics/translation
# https://betalist.com/topics/transportation
# https://betalist.com/topics/travel
# https://betalist.com/topics/travel-&-tourism
# Failed to fetch the page for travel-&-tourism, status code: 404
# https://betalist.com/topics/tutoring
# https://betalist.com/topics/tv-production
# https://betalist.com/topics/twitter-applications
# https://betalist.com/topics/unifed-communications
# https://betalist.com/topics/universities
# https://betalist.com/topics/university-students
# https://betalist.com/topics/usability
# https://betalist.com/topics/user-experience-design
# https://betalist.com/topics/user-testing
# https://betalist.com/topics/utilities
# https://betalist.com/topics/vacation-rentals
# https://betalist.com/topics/venture-capital
# https://betalist.com/topics/ventures-for-good
# https://betalist.com/topics/video
# https://betalist.com/topics/video-chat
# https://betalist.com/topics/video-conferencing
# https://betalist.com/topics/video-editing
# https://betalist.com/topics/video-games
# https://betalist.com/topics/video-on-demand
# https://betalist.com/topics/video-streaming
# https://betalist.com/topics/virtual-currency
# https://betalist.com/topics/virtualization
# https://betalist.com/topics/virtual-reality
# https://betalist.com/topics/virtual-workforces
# https://betalist.com/topics/virtual-worlds
# https://betalist.com/topics/visualization
# https://betalist.com/topics/visual-search
# https://betalist.com/topics/voice
# https://betalist.com/topics/voip
# https://betalist.com/topics/waste-management
# https://betalist.com/topics/wealth-management
# https://betalist.com/topics/wearables
# https://betalist.com/topics/web3
# https://betalist.com/topics/web-browsers
# https://betalist.com/topics/web-cms
# https://betalist.com/topics/web-design
# https://betalist.com/topics/web-development
# https://betalist.com/topics/web-hosting
# https://betalist.com/topics/web-tools
# https://betalist.com/topics/weddings
# https://betalist.com/topics/west-africa
# https://betalist.com/topics/wholesale
# https://betalist.com/topics/wine-and-spirits
# https://betalist.com/topics/wireless
# https://betalist.com/topics/women
# https://betalist.com/topics/work-from-home
# Failed to fetch the page for work-from-home, status code: 404
# https://betalist.com/topics/world
# https://betalist.com/topics/writers
# https://betalist.com/topics/writing-tools
# https://betalist.com/topics/young-adults
# Data saved to output_sites.json

# %%
import json
import os

# Path to the 'output.json' file
input_file_path = 'output.json'  # Adjust this to your file's location

# Path to the 'all_startups' folder where you want to save the split JSON files
folder_path = 'all_startups'  # Adjust this to your desired location

# Ensure the 'all_startups' folder exists
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Load the JSON data from the file
with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# Define the number of categories per file
categories_per_file = 30

# Split the data into chunks of 30 categories each
chunks = [data[i:i + categories_per_file] for i in range(0, len(data), categories_per_file)]

# Save each chunk to a separate JSON file within the 'all_startups' folder
for index, chunk in enumerate(chunks):
    filename = os.path.join(folder_path, f'output_part_{index + 1}.json')
    with open(filename, 'w', encoding='utf-8') as file:
        json.dump(chunk, file, ensure_ascii=False, indent=4)

print("Files saved successfully.")
# Out:
# Files saved successfully.

# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_details_from_url(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        title = soup.find('h2').get_text(strip=True) if soup.find('h2') else 'Title Not Found'
        main_content_div = soup.find('div', class_='main content')
        description = ' '.join(p.get_text(strip=True) for p in main_content_div.find_all('p')) if main_content_div else 'Description Not Found'
        return title, description
    else:
        print(f"Failed to fetch the page for URL: {url}, status code: {response.status_code}")
        return 'Title Not Found', 'Description Not Found'

def process_dataset_and_save_each_iteration(input_dataset, output_filename):
    base_url = "https://betalist.com"
    scraped_data = []

    for category_item in input_dataset:
        category = category_item["category"]
        for startup in category_item["startups"]:
            text = startup["text"]
            href = startup["href"]
            full_url = f"{base_url}{href}"
            title, description = scrape_details_from_url(full_url)
            
            # Append the current startup's scraped data
            scraped_data.append({
                "text": text,
                "href": href,
                "category": category,
                "title": title,
                "description": description
            })
            
            # Save to JSON file after processing each startup
            with open(output_filename, 'w', encoding='utf-8') as file:
                json.dump(scraped_data, file, ensure_ascii=False, indent=4)
    
    print(f"All data saved to {output_filename}")

# Assuming the input dataset is loaded from 'input_dataset.json'
with open('output_sites.json', 'r', encoding='utf-8') as file:
    input_dataset = json.load(file)

output_filename = 'scraped_website_details.json'
process_dataset_and_save_each_iteration(input_dataset, output_filename)
# Out:
# Failed to fetch the page for URL: https://betalist.com/startups/codulab, status code: 404
# Failed to fetch the page for URL: https://betalist.com/startups/wpflexiblepay, status code: 404
# Failed to fetch the page for URL: https://betalist.com/startups/linkgage, status code: 404
# Failed to fetch the page for URL: https://betalist.com/startups/let-s-remote, status code: 404
# All data saved to scraped_website_details.json
